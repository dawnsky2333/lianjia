# %% [markdown]
# # 链家网成都二手房可视化分析

# %% [markdown]
# 导入相应的模块

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from IPython.display import display
plt.style.use("fivethirtyeight")
sns.set_style({'font.sans-serif':['simhei','Arial']})
# %matplotlib inline

# %%
lianjia_df = pd.read_csv(r'D:/Git/Repositories/lianjia/lianjia/spiders/cd_information.csv')

# %%
lianjia_df.head()
# Out:
#       区   朝向 配备电梯        所在楼层          链家编号  房屋户型  房屋价格（单位：万元） 装修类型     建筑面积  \
# 0    高新    北    有  高楼层 (共32层)  106101048637  4室2厅        660.0   毛坯  202.86㎡
# 1    成华    南    有  中楼层 (共17层)  106100964658  2室2厅         95.5   精装   70.99㎡
# 2    金牛   西南    有  高楼层 (共34层)  106105123733  1室1厅         92.0   精装   47.32㎡
# 3    新都  南 北    有  中楼层 (共33层)  106104381786  4室2厅        128.0   毛坯   97.68㎡
# 4  天府新区   东南    有  低楼层 (共44层)  106104217345  3室2厅        193.0   精装  104.96㎡
#
#      建筑时间
# 0  2013年建
# 1  2006年建
# 2  2009年建
# 3  2017年建
# 4  2015年建

# %%
lianjia_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
# 区              2991 non-null object
# 朝向             2991 non-null object
# 配备电梯           2988 non-null object
# 所在楼层           2991 non-null object
# 链家编号           2991 non-null int64
# 房屋户型           2991 non-null object
# 房屋价格（单位：万元）    2990 non-null float64
# 装修类型           2988 non-null object
# 建筑面积           2991 non-null object
# 建筑时间           2991 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 233.8+ KB

# %%
lianjia_df['建筑面积']
# Out:
# 0       202.86㎡
# 1        70.99㎡
# 2        47.32㎡
# 3        97.68㎡
# 4       104.96㎡
# 5       131.99㎡
# 6       106.24㎡
# 7       123.67㎡
# 8        88.94㎡
# 9        79.85㎡
# 10       89.79㎡
# 11      153.67㎡
# 12        94.8㎡
# 13       82.85㎡
# 14      115.15㎡
# 15      108.76㎡
# 16          46㎡
# 17       82.88㎡
# 18       48.41㎡
# 19       73.59㎡
# 20       61.78㎡
# 21       67.34㎡
# 22       80.66㎡
# 23        51.6㎡
# 24       87.76㎡
# 25       80.08㎡
# 26       81.74㎡
# 27       79.57㎡
# 28         125㎡
# 29       134.5㎡
#          ...
# 2961     71.87㎡
# 2962    131.74㎡
# 2963    140.79㎡
# 2964    104.96㎡
# 2965      88.7㎡
# 2966    144.75㎡
# 2967     76.27㎡
# 2968        89㎡
# 2969    184.64㎡
# 2970     73.29㎡
# 2971       121㎡
# 2972    133.18㎡
# 2973    110.55㎡
# 2974     118.7㎡
# 2975    117.72㎡
# 2976      84.4㎡
# 2977    108.93㎡
# 2978    135.33㎡
# 2979     58.56㎡
# 2980    121.72㎡
# 2981     74.66㎡
# 2982    124.29㎡
# 2983    113.03㎡
# 2984    133.39㎡
# ...

# %%
lianjia_df['建筑时间'] = lianjia_df['建筑时间'].str.extract('(\d+)年建', expand=False)

# %%
lianjia_df['建筑面积'] = lianjia_df.建筑面积.apply(lambda x: eval(x.split('㎡')[0]))

# %%
lianjia_df
# Out:
#          区     朝向 配备电梯        所在楼层          链家编号  房屋户型  房屋价格（单位：万元） 装修类型  \
# 0       高新      北    有  高楼层 (共32层)  106101048637  4室2厅        660.0   毛坯
# 1       成华      南    有  中楼层 (共17层)  106100964658  2室2厅         95.5   精装
# 2       金牛     西南    有  高楼层 (共34层)  106105123733  1室1厅         92.0   精装
# 3       新都    南 北    有  中楼层 (共33层)  106104381786  4室2厅        128.0   毛坯
# 4     天府新区     东南    有  低楼层 (共44层)  106104217345  3室2厅        193.0   精装
# 5       锦江      南    有  低楼层 (共11层)  106104028521  3室2厅        215.0   简装
# 6       新都     东南    有  高楼层 (共18层)  106104142987  3室1厅        127.0   简装
# 7       双流      东    有  中楼层 (共18层)  106103922741  3室2厅        146.0   简装
# 8       青羊      南    无   低楼层 (共7层)  106102763151  2室2厅        103.5   精装
# 9     天府新区      南    无   高楼层 (共6层)  106105198611  2室2厅         97.0   简装
# 10      成华     东南    有   高楼层 (共8层)  106105044943  3室1厅        158.0   精装
# 11      青羊     西南    有  高楼层 (共18层)  106102898264  4室2厅        355.0   精装
# ...
